# %% [markdown]
# # Notebook BERTopic Avancé
#
# _A.Morin, E.Schultz - Atelier Méthodes - 7 Mai 2026_
#
# Ce notebook explore chaque composante de la pipeline BERTopic et illustre l'impact des principaux hyperparamètres.
#
# ## Télécharger les librairies importantes
#
# Pour les configurations locales, attention à bien gérer vos espaces virtuels (si pas déjà fait)

# %%
# Retirer les # avant de lancer
# !curl https://raw.githubusercontent.com/emilienschultz/slides-bertopic/refs/heads/main/material/requirements.txt > requirements.txt
# !pip install -r requirements.txt
# !wget https://raw.githubusercontent.com/emilienschultz/slides-bertopic/refs/heads/main/material/theses-soutenues-curated-stratified.csv

# %%
import pandas as pd
import numpy as np
from bertopic import BERTopic
from umap import UMAP 
from hdbscan import HDBSCAN 
from datasets import load_from_disk
from sklearn.feature_extraction.text import CountVectorizer 
from stopwordsiso import stopwords

# %% [markdown]
# On selectionne tout le jeu de données désormais : 6500 documents.

# %%
df = pd.read_csv("./theses-soutenues-curated-stratified.csv")
docs = df["resumes.fr"].to_list()
df.head(5)

# %% [markdown]
# ## Observer l'impact du changement de modèle de plongement

# %%
topic_model = BERTopic(
    language="french", 
    embedding_model = "Alibaba-NLP/gte-multilingual-base",
)
topic_model.fit(documents=docs)

# %% [markdown]
# Cette cellule est très longue à faire tourner. Pour éviter l'attente on peut pré-calculer les embeddings et les renseigner pour éviter les calculs de plongements.
#
# [Instructions pour précalculer les embeddings](https://css-polytechnique.github.io/css-ipp-materials/pages/bertopic-tutorial.html#precompute-your-embeddings).

# %%
# !unzip embeddings.zip
# Out:
# Archive:  embeddings.zip
#    creating: embeddings
#   inflating: __MACOSX/._embeddings
#   inflating: embeddings/.DS_Store
#   inflating: __MACOSX/embeddings/._.DS_Store
#    creating: embeddings/all-MiniLM-L6-v2-en
#   inflating: __MACOSX/embeddings/._all-MiniLM-L6-v2-en
#    creating: embeddings/all-MiniLM-L6-v2-fr
#   inflating: __MACOSX/embeddings/._all-MiniLM-L6-v2-fr
#    creating: embeddings/all-MiniLM-L6-v2-en-SBERT
#   inflating: __MACOSX/embeddings/._all-MiniLM-L6-v2-en-SBERT
#    creating: embeddings/gte-multilingual-base-en-SBERT
#   inflating: __MACOSX/embeddings/._gte-multilingual-base-en-SBERT
#   inflating: embeddings/README.md
#   inflating: __MACOSX/embeddings/._README.md
#    creating: embeddings/all-MiniLM-L6-v2-fr-SBERT
#   inflating: __MACOSX/embeddings/._all-MiniLM-L6-v2-fr-SBERT
#    creating: embeddings/gte-multilingual-base-fr-SBERT
#   inflating: __MACOSX/embeddings/._gte-multilingual-base-fr-SBERT
#    creating: embeddings/gte-multilingual-base-fr
#   inflating: __MACOSX/embeddings/._gte-multilingual-base-fr
#    creating: embeddings/gte-multilingual-base-en
#   inflating: __MACOSX/embeddings/._gte-multilingual-base-en
#    creating: embeddings/qwenO6b-en
#   inflating: __MACOSX/embeddings/._qwenO6b-en
#   inflating: embeddings/all-MiniLM-L6-v2-en/state.json
#   inflating: __MACOSX/embeddings/all-MiniLM-L6-v2-en/._state.json
#   inflating: embeddings/all-MiniLM-L6-v2-en/dataset_info.json
#   inflating: __MACOSX/embeddings/all-MiniLM-L6-v2-en/._dataset_info.json
#   inflating: embeddings/all-MiniLM-L6-v2-en/data-00000-of-00001.arrow
#   inflating: __MACOSX/embeddings/all-MiniLM-L6-v2-en/._data-00000-of-00001.arrow
#   inflating: embeddings/all-MiniLM-L6-v2-fr/state.json
#   inflating: __MACOSX/embeddings/all-MiniLM-L6-v2-fr/._state.json
#   inflating: embeddings/all-MiniLM-L6-v2-fr/dataset_info.json
#   inflating: __MACOSX/embeddings/all-MiniLM-L6-v2-fr/._dataset_info.json
#   inflating: embeddings/all-MiniLM-L6-v2-fr/data-00000-of-00001.arrow
#   inflating: __MACOSX/embeddings/all-MiniLM-L6-v2-fr/._data-00000-of-00001.arrow
#   inflating: embeddings/all-MiniLM-L6-v2-en-SBERT/state.json
#   inflating: __MACOSX/embeddings/all-MiniLM-L6-v2-en-SBERT/._state.json
#   inflating: embeddings/all-MiniLM-L6-v2-en-SBERT/dataset_info.json
#   inflating: __MACOSX/embeddings/all-MiniLM-L6-v2-en-SBERT/._dataset_info.json
#   inflating: embeddings/all-MiniLM-L6-v2-en-SBERT/data-00000-of-00001.arrow
#   inflating: __MACOSX/embeddings/all-MiniLM-L6-v2-en-SBERT/._data-00000-of-00001.arrow
#   inflating: embeddings/gte-multilingual-base-en-SBERT/state.json
#   inflating: __MACOSX/embeddings/gte-multilingual-base-en-SBERT/._state.json
#   inflating: embeddings/gte-multilingual-base-en-SBERT/dataset_info.json
#   inflating: __MACOSX/embeddings/gte-multilingual-base-en-SBERT/._dataset_info.json
#   inflating: embeddings/gte-multilingual-base-en-SBERT/data-00000-of-00001.arrow
#   inflating: __MACOSX/embeddings/gte-multilingual-base-en-SBERT/._data-00000-of-00001.arrow
#   inflating: embeddings/all-MiniLM-L6-v2-fr-SBERT/state.json
#   inflating: __MACOSX/embeddings/all-MiniLM-L6-v2-fr-SBERT/._state.json
#   inflating: embeddings/all-MiniLM-L6-v2-fr-SBERT/dataset_info.json
#   inflating: __MACOSX/embeddings/all-MiniLM-L6-v2-fr-SBERT/._dataset_info.json
#   inflating: embeddings/all-MiniLM-L6-v2-fr-SBERT/data-00000-of-00001.arrow
#   inflating: __MACOSX/embeddings/all-MiniLM-L6-v2-fr-SBERT/._data-00000-of-00001.arrow
#   inflating: embeddings/gte-multilingual-base-fr-SBERT/state.json
#   inflating: __MACOSX/embeddings/gte-multilingual-base-fr-SBERT/._state.json
#   inflating: embeddings/gte-multilingual-base-fr-SBERT/dataset_info.json
#   inflating: __MACOSX/embeddings/gte-multilingual-base-fr-SBERT/._dataset_info.json
#   inflating: embeddings/gte-multilingual-base-fr-SBERT/data-00000-of-00001.arrow
#   inflating: __MACOSX/embeddings/gte-multilingual-base-fr-SBERT/._data-00000-of-00001.arrow
#   inflating: embeddings/gte-multilingual-base-fr/state.json
#   inflating: __MACOSX/embeddings/gte-multilingual-base-fr/._state.json
#   inflating: embeddings/gte-multilingual-base-fr/dataset_info.json
#   inflating: __MACOSX/embeddings/gte-multilingual-base-fr/._dataset_info.json
#   inflating: embeddings/gte-multilingual-base-fr/data-00000-of-00001.arrow
#   inflating: __MACOSX/embeddings/gte-multilingual-base-fr/._data-00000-of-00001.arrow
#   inflating: embeddings/gte-multilingual-base-en/state.json
#   inflating: __MACOSX/embeddings/gte-multilingual-base-en/._state.json
#   inflating: embeddings/gte-multilingual-base-en/dataset_info.json
#   inflating: __MACOSX/embeddings/gte-multilingual-base-en/._dataset_info.json
#   inflating: embeddings/gte-multilingual-base-en/data-00000-of-00001.arrow
#   inflating: __MACOSX/embeddings/gte-multilingual-base-en/._data-00000-of-00001.arrow
#   inflating: embeddings/qwenO6b-en/state.json
#   inflating: __MACOSX/embeddings/qwenO6b-en/._state.json
#   inflating: embeddings/qwenO6b-en/dataset_info.json
#   inflating: __MACOSX/embeddings/qwenO6b-en/._dataset_info.json
#   inflating: embeddings/qwenO6b-en/data-00000-of-00001.arrow
#   inflating: __MACOSX/embeddings/qwenO6b-en/._data-00000-of-00001.arrow

# %%
ds = load_from_disk(f"./embeddings/gte-multilingual-base-fr-SBERT")
docs = np.array(ds[f"resumes.fr"]) # 6500 rows
embeddings = np.array(ds["embedding"])			 # Shape : 6500 x 768

topic_model = BERTopic(
    language="french", 
)
topic_model.fit(
    documents=docs,
    embeddings=embeddings # renseigne les plongements ici
)

# %%
topic_model.get_topic_info()

# %%
topic_model.visualize_documents(
    docs = docs,
    hide_annotations = True,
    embeddings=embeddings # Renseigner les plongements ici
)

# %% [markdown]
# **On continue l'exploration avec ces embeddings: `"./embeddings/gte-multilingual-base-fr-SBERT"`**

# %% [markdown]
# ## Observer l'impact de UMAP

# %%
umap_model = UMAP(
    n_neighbors = 50,  # default : 15
    n_components = 3,  # default : 5
    # Default parameters
    metric = "cosine",
    min_dist=0.0,
    low_memory = False, 
    # random_state=42 <--- Pour retirer l'aléatoire
)


topic_model = BERTopic(
    language="french", 
)
topic_model.fit(
    documents=docs,
    embeddings=embeddings # renseigne les plongements ici
)

# %%
topic_model.get_topic_info()

# %%
topic_model.visualize_documents(
    docs = docs,
    hide_annotations = True,
    embeddings=embeddings # Renseigner les plongements ici
)

# %%
topic_model.visualize_hierarchy()

# %% [markdown]
# ### Observer l'impact de UMAP sur les embeddings

# %%
umap_model_for_visualisation = UMAP(
    n_neighbors = 50,  # default : 15 <-- changer valeur
    n_components = 2,  # Doit forcer à deux pour pouvoir les visualiser
    # Default parameters
    metric = "cosine",
    min_dist=0.0,
    low_memory = False 
    # random_state=42 <--- Pour retirer l'aléatoire
) 

reduced_embeddings = umap_model_for_visualisation.fit_transform(embeddings)

topic_model.visualize_documents(
    docs = docs,
    reduced_embeddings = reduced_embeddings,
    hide_annotations = True, 
    hide_document_hover = True,
    height = 600, 
    width = 1000
)

# %% [markdown]
# ## Observer l'impact de HDBSCAN

# %%
hdbscan_model = HDBSCAN(
    min_cluster_size=50,  # <--- changer la valeur
    # Default parameters 
    prediction_data=True
)

topic_model = BERTopic(language = "french", hdbscan_model=hdbscan_model)
topic_model.fit(documents=docs, embeddings=embeddings)

# %%
topic_model.get_topic_info()

# %%
topic_model.visualize_documents(
    docs = docs,
    hide_annotations = True,
    embeddings=embeddings # Renseigner les plongements ici
)

# %%
topic_model.visualize_hierarchy()

# %% [markdown]
# ## Observer l'impact de CountVectorizer

# %%
vectorizer_model = CountVectorizer(stop_words = list(stopwords("fr")))

topic_model = BERTopic(language = "french", vectorizer_model = vectorizer_model)
topic_model.fit(documents=docs, embeddings=embeddings)

# %%
topic_model.get_topic_info()

# %% [markdown]
# ## Exercice: Implémenter une pipeline complète en modifiant chaque élément si besoin

# %%
# à toi de jouer!
